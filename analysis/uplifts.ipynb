# %%
# %matplotlib inline

import sys
import os
import copy
import pickle
import gzip
import pandas as pd
from pprint import pprint

import libmozdata.config as config

config.set_config(config.ConfigIni('../config.ini'))

from libmozdata import bugzilla
from libmozdata import patchanalysis

# %%
channel = 'release'

# %%
bugs = []
try:
    with gzip.GzipFile('bugs_' + channel + '_uplifts.pickle.gz', 'rb') as f:
        bugs += pickle.load(f)
except IOError:
    pass

print('Loaded ' + str(len(bugs)) + ' bugs.')

INCLUDE_FIELDS = [
  'id', 'flags', 'depends_on', 'keywords', 'blocks', 'whiteboard', 'resolution', 'status',
  'url', 'version', 'summary', 'priority', 'product', 'component', 'severity',
  'platform', 'op_sys', 'cc', 'assigned_to', 'creator',
]

ATTACHMENT_INCLUDE_FIELDS = [
  'flags', 'is_patch', 'creator', 'content_type',
]

INCLUDE_FIELDS_QUERY = 'include_fields=' + ','.join(INCLUDE_FIELDS)

found = []
finished = False
while not finished:
    bugs_dict = dict()

    def bughandler(bug, data):
        bugid = str(bug['id'])

        if bugid not in bugs_dict:
            bugs_dict[bugid] = dict()

        for k, v in bug.items():
            bugs_dict[bugid][k] = v

    def commenthandler(bug, bugid, data):
        bugid = str(bugid)

        if bugid not in bugs_dict:
            bugs_dict[bugid] = dict()

        bugs_dict[bugid]['comments'] = bug['comments']

    def attachmenthandler(bug, bugid, data):
        bugid = str(bugid)

        if bugid not in bugs_dict:
            bugs_dict[bugid] = dict()

        bugs_dict[bugid]['attachments'] = bug

    def historyhandler(bug, data):
        bugid = str(bug['id'])

        if bugid not in bugs_dict:
            bugs_dict[bugid] = dict()

        bugs_dict[bugid]['history'] = bug['history']

    bugzilla.Bugzilla('limit=200&offset=' + str(len(bugs)) + '&o1=anywords&v1=approval-mozilla-' + channel + '&f1=flagtypes.name&' + INCLUDE_FIELDS_QUERY, bughandler=bughandler, commenthandler=commenthandler, attachmenthandler=attachmenthandler, attachment_include_fields=ATTACHMENT_INCLUDE_FIELDS, historyhandler=historyhandler).get_data().wait()

    found = [bug for bug in bugs_dict.values()]

    print('Found ' + str(len(found)) + ' bugs.')

    bugs += found

    with gzip.GzipFile('bugs_' + channel + '_uplifts.pickle.gz', 'wb') as f:
        pickle.dump(bugs, f)

    if len(found) < 200:
        finished = True
# Out:
# Loaded 639 bugs.
# Found 0 bugs.

# %%
len(bugs)
# Out:
# 639

# %%
bug_set = []
try:
    with gzip.GzipFile('bug_set_' + channel + '_uplifts.pickle.gz', 'rb') as f:
        bug_set += pickle.load(f)
except IOError:
    pass

i = len(bug_set)

for bug in bugs[len(bug_set):]:
    # Skip this bug because it's crazy.
    if bug['id'] == 784739:
        continue

    print(str(i) + ' ' + str(bug['id']))
    sys.stdout.flush()
    i += 1

    bug_data = {}

    try:
        bug_data.update(patchanalysis.bug_analysis(bug))

        assert 'changes_size' in bug_data, 'changes_size not in bug_data'
        assert bug_data['changes_size'] > 0, 'changes_size too small'
    except Exception as e:
        print('bug_analysis error with bug ' + str(bug['id']) + ': ' + str(e))

    try:
        bug_data.update(patchanalysis.uplift_info(bug, channel))
    except Exception as e:
        print('uplift_info error with bug ' + str(bug['id']) + ': ' + str(e))

    bug_data['product'] = bug['product']
    bug_data['component'] = bug['component']
    bug_data['platform'] = bug['platform']
    bug_data['op_sys'] = bug['op_sys']
    bug_data['version'] = bug['version']
    bug_data['priority'] = bug['priority']

    bug_set.append(bug_data)

with gzip.GzipFile('bug_set_' + channel + '_uplifts.pickle.gz', 'wb') as f:
    pickle.dump(bug_set, f)

len(bug_set)
# Out:
# 639

# %%
df = pd.DataFrame(bug_set)
df.head()
# Out:
#    backout_num  blocks  changes_size  code_churn_last_3_releases  \
# 0            0       3           194                         526
# 1            0       0            22                           2
# 2            0       2           658                          91
# 3            0       3            17                          26
# 4            0       0            24                         219
#
#    code_churn_overall  comments         component  crashes  depends_on  \
# 0                3770        69      Build Config       20           1
# 1                   8        16      Build Config        0           0
# 2                 179        97          Plug-ins     2004           4
# 3                  85        88  Networking: HTTP      163          22
# 4                2027        10      Build Config        0           0
#
#    developer_familiarity_last_3_releases     ...         release_delta  \
# 0                                     12     ...      37 days 03:24:10
# 1                                      1     ...      21 days 17:42:03
# 2                                     32     ...      24 days 08:41:08
# 3                                      2     ...      34 days 10:33:20
# 4                                      0     ...      40 days 14:42:02
#
#    response_delta  reviewer_familiarity_last_3_releases  \
# 0 2 days 15:05:37                                     5
# 1 0 days 03:39:37                                     0
# 2 0 days 00:00:00                                     3
# 3 0 days 01:52:45                                     2
# 4 0 days 00:00:00                                     0
#
#   reviewer_familiarity_overall test_changes_size uplift_accepted  \
# 0                           25                 0           False
# 1                            0                 0            True
# 2                            7                 0           False
# 3                            3                 0            True
# 4                            0                 0            True
#
#                                        uplift_author  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'real_name': ':Ehsan Akhgari', 'is_new': Fals...
# 4  {'real_name': 'Brad Lassey [:blassey] (use nee...
#
#                                       uplift_comment  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'tags': [], 'time': '2012-09-04T15:42:15Z', '...
# 4  {'tags': [], 'time': '2012-10-05T00:42:17Z', '...
#
#                                                users      version
# 0  {'authors': {'mwu.code@gmail.com'}, 'assignee'...        Trunk
# 1  {'authors': {'bhearsum@mozilla.com'}, 'assigne...  unspecified
# 2  {'authors': {'jaas@kflag.net'}, 'assignee': {'...  unspecified
# 3  {'authors': {'josh@joshmatthews.net', 'ehsan@m...    15 Branch
# 4  {'authors': {'blassey.bugs@lassey.us'}, 'assig...  unspecified
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 639 entries, 0 to 638
# Data columns (total 28 columns):
# backout_num                              627 non-null float64
# blocks                                   627 non-null float64
# changes_size                             620 non-null float64
# code_churn_last_3_releases               620 non-null float64
# code_churn_overall                       620 non-null float64
# comments                                 627 non-null float64
# component                                639 non-null object
# crashes                                  620 non-null float64
# depends_on                               627 non-null float64
# developer_familiarity_last_3_releases    620 non-null float64
# developer_familiarity_overall            620 non-null float64
# landing_delta                            637 non-null timedelta64[ns]
# modules_num                              620 non-null float64
# op_sys                                   639 non-null object
# platform                                 639 non-null object
# priority                                 639 non-null object
# product                                  639 non-null object
# r-ed_patches                             627 non-null float64
# release_delta                            637 non-null timedelta64[ns]
# response_delta                           637 non-null timedelta64[ns]
# reviewer_familiarity_last_3_releases     620 non-null float64
# reviewer_familiarity_overall             620 non-null float64
# test_changes_size                        620 non-null float64
# uplift_accepted                          637 non-null object
# uplift_author                            529 non-null object
# uplift_comment                           529 non-null object
# users                                    627 non-null object
# version                                  639 non-null object
# dtypes: float64(15), object(10), timedelta64[ns](3)
# memory usage: 144.8+ KB

# %%
df.describe()
# Out:
#        backout_num      blocks  changes_size  code_churn_last_3_releases  \
# count   627.000000  627.000000    620.000000                  620.000000
# mean      0.114833    1.125997    319.519355                   62.983871
# std       0.378605    1.095333   2922.126448                  106.124990
# min       0.000000    0.000000      0.000000                    0.000000
# 25%       0.000000    0.000000     23.000000                    8.000000
# 50%       0.000000    1.000000     52.000000                   24.500000
# 75%       0.000000    2.000000    137.250000                   72.500000
# max       3.000000    8.000000  67402.000000                 1251.000000
#
#        code_churn_overall    comments         crashes  depends_on  \
# count          620.000000  627.000000      620.000000  627.000000
# mean           471.051613   37.154705     5145.640323    0.647528
# std            839.479678   30.307265    78090.052111    1.710288
# min              0.000000    3.000000        0.000000    0.000000
# 25%             36.000000   18.000000        0.000000    0.000000
# 50%            126.000000   29.000000        2.000000    0.000000
# 75%            460.500000   45.000000      198.000000    1.000000
# max           6360.000000  316.000000  1726021.000000   22.000000
#
#        developer_familiarity_last_3_releases  developer_familiarity_overall  \
# count                             620.000000                     620.000000
# mean                                7.611290                      28.146774
# std                                28.435379                      70.790707
# min                                 0.000000                       0.000000
# 25%                                 0.000000                       1.000000
# 50%                                 2.000000                       9.000000
# 75%                                 8.000000                      28.000000
# max                               627.000000                    1216.000000
#
#                  landing_delta  modules_num  r-ed_patches  \
# count                      637   620.000000    627.000000
# mean    2 days 17:54:30.970172     1.495161      0.121212
# std    23 days 20:58:17.664078     1.071729      0.467452
# min        -277 days +18:16:14     0.000000      0.000000
# 25%          -1 days +06:52:08     1.000000      0.000000
# 50%            0 days 00:02:45     1.000000      0.000000
# 75%            2 days 23:34:30     2.000000      0.000000
# max          141 days 19:47:45    10.000000      5.000000
#
#                  release_delta          response_delta  \
# count                      637                     637
# mean   23 days 00:56:58.428571  2 days 04:25:21.697017
# std    14 days 14:44:54.409301  5 days 09:39:17.493146
# min            0 days 06:04:39         0 days 00:00:00
# 25%            7 days 12:44:50         0 days 00:00:00
# 50%           21 days 17:42:03         0 days 03:18:01
# 75%           35 days 08:33:21         1 days 20:05:54
# max           54 days 13:41:48        59 days 00:14:34
#
#        reviewer_familiarity_last_3_releases  reviewer_familiarity_overall  \
# count                            620.000000                    620.000000
# mean                               7.164516                     32.893548
# std                               40.521145                    159.436736
# min                                0.000000                      0.000000
# 25%                                0.000000                      0.000000
# 50%                                0.000000                      1.000000
# 75%                                3.000000                     15.250000
# max                              667.000000                   2907.000000
#
#        test_changes_size
# count         620.000000
# mean          103.141935
# std          1185.934258
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max         25754.000000

# %%
cross_tab = pd.crosstab(df['uplift_accepted'], df['r-ed_patches'])
cross_tab
# Out:
# r-ed_patches       0   1  2  3  5
# uplift_accepted
# False            143  14  0  0  1
# True             429  28  9  2  1

# %%
cross_tab_pct = cross_tab.div(cross_tab.sum(1).astype(float), axis=0)
cross_tab_pct.plot(kind='bar', stacked=True)

# %%
df.backout_num[df.uplift_accepted == True].plot(kind='kde')
df.backout_num[df.uplift_accepted == False].plot(kind='kde')

# %%
df[df.uplift_accepted == True][['changes_size', 'code_churn_last_3_releases', 'developer_familiarity_last_3_releases', 'reviewer_familiarity_last_3_releases']].describe()
# Out:
#        changes_size  code_churn_last_3_releases  \
# count    464.000000                  464.000000
# mean     162.079741                   64.530172
# std      521.644807                  104.734938
# min        0.000000                    0.000000
# 25%       23.000000                    9.000000
# 50%       52.000000                   25.000000
# 75%      137.250000                   79.250000
# max     9864.000000                 1251.000000
#
#        developer_familiarity_last_3_releases  \
# count                             464.000000
# mean                                6.243534
# std                                10.364364
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 2.500000
# 75%                                 8.000000
# max                                99.000000
#
#        reviewer_familiarity_last_3_releases
# count                            464.000000
# mean                               5.683190
# std                               29.157442
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                3.000000
# max                              424.000000

# %%
df[df.uplift_accepted == False][['changes_size', 'code_churn_last_3_releases', 'developer_familiarity_last_3_releases', 'reviewer_familiarity_last_3_releases']].describe()
# Out:
#        changes_size  code_churn_last_3_releases  \
# count    156.000000                  156.000000
# mean     787.801282                   58.384615
# std     5743.907159                  110.373294
# min        0.000000                    0.000000
# 25%       23.750000                    6.000000
# 50%       49.000000                   21.000000
# 75%      129.750000                   49.500000
# max    67402.000000                  687.000000
#
#        developer_familiarity_last_3_releases  \
# count                             156.000000
# mean                               11.679487
# std                                53.720902
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 2.000000
# 75%                                 8.250000
# max                               627.000000
#
#        reviewer_familiarity_last_3_releases
# count                            156.000000
# mean                              11.570513
# std                               63.179530
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                3.250000
# max                              667.000000

# %%
df.hist(figsize=(40,40))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3f7e9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3eec320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3eb3668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3e67cf8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3e32f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3df2828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3dc1518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3dfec88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3d479b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3d0f7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3ccfd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3c206a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3c4b3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3c1a390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3be0b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff9e3b9f7f0>]], dtype=object)

# %%
df['product'].value_counts().plot.pie(figsize=(8,8))

# %%
df.op_sys.value_counts().plot.pie(figsize=(8,8))

# %%
df.platform.value_counts().plot.pie(figsize=(8,8))

# %%
df.version.value_counts().plot.pie(figsize=(8,8))

# %%
df.priority.value_counts().plot.pie(figsize=(8,8))
